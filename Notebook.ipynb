# %%
import matplotlib.pyplot as plt
import plots_drawer

pl_dr = plots_drawer.PlotDrawer()
pl_dr.draw_plots('deviation.json')
# Out:
# ['C:\\Users\\Vladimir\\PycharmProjects\\draw_plots\\plots\\plot_floor_max vs ceiling_max.png',
#  'C:\\Users\\Vladimir\\PycharmProjects\\draw_plots\\plots\\plot_floor_mean vs ceiling_mean.png',
#  'C:\\Users\\Vladimir\\PycharmProjects\\draw_plots\\plots\\plot_floor_min vs ceiling_min.png',
#  'C:\\Users\\Vladimir\\PycharmProjects\\draw_plots\\plots\\plot_gt_corners vs rb_corners.png']
