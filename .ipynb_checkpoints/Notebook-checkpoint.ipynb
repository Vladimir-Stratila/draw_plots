# %%
import matplotlib.pyplot as plt
import plots_drawer

pl_dr = plots_drawer.PlotDrawer()
plt = pl_dr.draw_plots('deviation.json')

plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12220/3399484339.py in <module>
#       3
#       4 pl_dr = plots_drawer.PlotDrawer()
# ----> 5 plt = pl_dr.draw_plots('deviation.json')
#       6
#       7 plt.show
#
# ~\PycharmProjects\draw_plots\plots_drawer.py in draw_plots(self, json_file)
#      23         # plot_ceiling_min = data["ceiling_min"].plot()
#      24         # plot_vs = data.plot.scatter(x="floor_mean", y="ceiling_mean", alpha=0.5)
# ---> 25         plt.figure(figsize=(10, 5))
#      26         # plt.plot(data["gt_corners"], data["rb_corners"])
#      27         # plt.hist(data["mean"])
#
# AttributeError: 'list' object has no attribute 'get_figure'
